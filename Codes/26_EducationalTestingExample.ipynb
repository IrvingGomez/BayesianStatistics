# %% [markdown]
# # Example: parallel experiments in eight schools

# %%
import numpy as np
import pandas as pd

import pymc as pm
import arviz as az

from scipy.stats import norm, chi2

import matplotlib.pyplot as plt

from scipy.special import logsumexp

# %% [markdown]
# A study was performed for the Educational Testing Service to analyze the effects of special coaching programs on test scores. Separate randomized experiments were performed to estimate the effects of coaching programs for the SAT-V (Scholastic Aptitude Test-Verbal) in each of eight high schools. We consider the sampling variances known, for all practical purposes, because the sample sizes in all the eight experiments were relatively large.

# %%
DatGroup = pd.DataFrame(
    {
        'Group': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
        , 'MeanGroup': [28, 8, -3, 7, -1, 1, 18, 12]
        , 'SigmaJ': [15, 10, 16, 11, 9, 11, 10, 18]
    }
)

DatGroup['Sigma2J'] = DatGroup['SigmaJ']**2

J = len(DatGroup)

ALPHA_LEVEL = 0.05

# %% [markdown]
# ## Building the models by hand

# %% [markdown]
# ### Separate estimates

# %% [markdown]
# We can consider each experiment separately with the following model: $$Y_j|\theta_j\sim\textsf{Normal}(\theta_j,\sigma_j^2)$$ and $$p(\theta_j)\propto 1,$$ so the posterior would be $$\theta_j|Y_j\sim\textsf{Normal}(Y_j,\sigma_j^2).$$

# %%
LowPosteriorSeparate = norm.ppf(ALPHA_LEVEL/2, loc=DatGroup['MeanGroup'], scale=DatGroup['SigmaJ'])
UppPosteriorSeparate = norm.ppf(1-ALPHA_LEVEL/2, loc=DatGroup['MeanGroup'], scale=DatGroup['SigmaJ'])

# %%
for j in range(J):
    plt.plot(
        [j, j],
        [LowPosteriorSeparate[j], UppPosteriorSeparate[j]],
        color='k')
    
plt.scatter(range(J), DatGroup['MeanGroup'], marker='D', color='k')

plt.xticks(ticks=range(J), labels=DatGroup['Group'])
plt.xlabel("School")
plt.ylabel(r"95% hightest posterior density for each $\theta$")
# Out:
# Text(0, 0.5, '95% hightest posterior density for each $\\theta$')

# %% [markdown]
# Treatening each experiment separately yields 95% posterior intervals which overlap substantially.

# %% [markdown]
# ### Complete pooling estimate

# %% [markdown]
# The general overlap in the posterior intervals based on independent analyses suggests that all experiments might be estimating the same quantity. Under the hypothesis that all experiments have the same effect and produce independent estimates of this common effect, we could treat the data as eight normally distributed observations: $$Y_j\sim\textsf{Normal}(\theta,\sigma_j^2).$$
#
# If we model $p(\theta)\propto 1$ then $\theta|\bm{Y}\sim\textsf{Normal}(\bar{Y}_{\cdot\cdot}, \varphi^2)$, where $$\bar{Y}_{\cdot\cdot}=\frac{\sum_{j=1}^J \frac{1}{\sigma_j^2}Y_j}{\sum_{j=1}^J \frac{1}{\sigma_j^2}}$$ and $$\varphi^2=\frac{1}{\sum_{j=1}^J\frac{1}{\sigma_j^2}}$$

# %%
HatMuEmpirical = np.average(DatGroup['MeanGroup'], weights=1 / DatGroup['Sigma2J'])
VarPooledEstimate = 1/sum(1/DatGroup['Sigma2J'])

# %% [markdown]
# To know the goodness-of-fit of the model we can consider the posterior predictive, which would be given by $$Y_j|\mathbf{Y}\sim\textsf{Normal}(\bar{Y}_{\cdot\cdot}, \sigma_j^2+\varphi^2)$$

# %%
DatGroup['LowPredictionPooled'] = norm.ppf(
    q = 0.025
    , loc = HatMuEmpirical
    , scale = np.sqrt(DatGroup['Sigma2J'] + VarPooledEstimate)
)

DatGroup['UppPredictionPooled'] = norm.ppf(
    q = 0.975
    , loc = HatMuEmpirical
    , scale = np.sqrt(DatGroup['Sigma2J'] + VarPooledEstimate)
)

# %%
plt.plot(
    [DatGroup['MeanGroup'].min(), DatGroup['MeanGroup'].max()],
    [DatGroup['MeanGroup'].min(), DatGroup['MeanGroup'].max()],
    color='r', linestyle='--'
)

plt.scatter(DatGroup['MeanGroup'], [HatMuEmpirical]*J, marker='D', color='k')

for j in range(J):
    plt.plot(
        [DatGroup['MeanGroup'][j], DatGroup['MeanGroup'][j]],
        [DatGroup['LowPredictionPooled'][j], DatGroup['UppPredictionPooled'][j]]
        , color='k'
    )

plt.xlabel(r"$Y_j$")
plt.ylabel(r"95% prediction interval for each $Y_j$")
# Out:
# Text(0, 0.5, '95% prediction interval for each $Y_j$')

# %% [markdown]
# ### Hierarchical model

# %%
def VMuFunc(tau):
    return 1 / sum(1/(DatGroup['Sigma2J'] + tau**2))

VMuFunc = np.vectorize(VMuFunc)

def HatMuFunc(tau):
    return sum(DatGroup['MeanGroup'] / (DatGroup['Sigma2J'] + tau**2)) * VMuFunc(tau)

HatMuFunc = np.vectorize(HatMuFunc)

def PosteriorTau(tau):

    a = np.log(VMuFunc(tau))
    b = np.sum(np.log(DatGroup['Sigma2J'] + tau**2))
    c = np.sum((DatGroup['MeanGroup'] - HatMuFunc(tau))**2 / (DatGroup['Sigma2J'] + tau**2))

    return np.exp(0.5 * (a - b - c))

PosteriorTau = np.vectorize(PosteriorTau)

def VThetaFuncAux(j, tau):
    DatAux = DatGroup[DatGroup['Group']== j]
    return 1 / (1 / DatAux['Sigma2J'] + 1/tau**2)

VThetaFuncAux = np.vectorize(VThetaFuncAux)

def HatThetaFunc(j, tau):
    DatAux = DatGroup[DatGroup['Group']== j]
    return (DatAux['MeanGroup'] / DatAux['Sigma2J'] + HatMuFunc(tau) / tau**2) * VThetaFuncAux(j, tau)

HatThetaFunc = np.vectorize(HatThetaFunc)

def StdThetaFunc(j, tau):
    return np.sqrt(VThetaFuncAux(j, tau) + 1/tau**4 * VMuFunc(tau) * VThetaFuncAux(j, tau)**2)

StdThetaFunc = np.vectorize(StdThetaFunc)

# %% [markdown]
# We get the MAP for $\tau$ and calculate an approx. confidence interval.

# %%
TauVect = np.linspace(0.01, 30, num=100)
PosteriorTauVect = PosteriorTau(TauVect)
HatTauFull = TauVect[np.argmax(PosteriorTauVect)]

NormalizedPosteriorTau =  PosteriorTauVect / PosteriorTau(HatTauFull)
CutLevel = np.exp(-0.5 * chi2.ppf(1-ALPHA_LEVEL, df=1))

LowConfidenceTau = TauVect[NormalizedPosteriorTau > CutLevel][0]
UppConfidenceTau = TauVect[NormalizedPosteriorTau > CutLevel][-1]

# %% [markdown]
# Normalized posterior density of $\tau$

# %%
plt.plot(TauVect, NormalizedPosteriorTau, color='rebeccapurple')
plt.hlines(CutLevel, LowConfidenceTau, UppConfidenceTau, ls='--', color='k', label='Credible Interval')
plt.scatter(HatTauFull, CutLevel, marker='o', s=75, label=r'$\hat\tau^{MAP}|\sigma^2$')

plt.xlabel(r'$\tau$')
plt.ylabel(r'$p(\tau|\sigma^2)$')

plt.yticks([], [])
plt.legend()

# %% [markdown]
# We get a full Bayesian estimate for $\mu$ using $\hat{\mu}$ evaluated in the MAP of $\tau$. And compute a confidence interval.

# %%
HatMuFull = HatMuFunc(HatTauFull).reshape(1,)[0]
LowConfidenceMu = HatMuFull - np.sqrt(VMuFunc(HatTauFull)) * norm.ppf(1 - ALPHA_LEVEL / 2)
UppConfidenceMu = HatMuFull + np.sqrt(VMuFunc(HatTauFull)) * norm.ppf(1 - ALPHA_LEVEL / 2)

# %%
MuVect = np.linspace(LowConfidenceMu - np.sqrt(VMuFunc(HatTauFull)), UppConfidenceMu + np.sqrt(VMuFunc(HatTauFull)))

# %%
CutLevel = norm.pdf(LowConfidenceMu, loc=HatMuFull, scale=np.sqrt(VMuFunc(HatTauFull)))

plt.plot(MuVect, norm.pdf(MuVect, loc=HatMuFull, scale=np.sqrt(VMuFunc(HatTauFull))), color='rebeccapurple')
plt.hlines(CutLevel, LowConfidenceMu, UppConfidenceMu, ls='--', color='k', label='Credible Interval')
plt.scatter(HatMuFull, CutLevel, marker='o', s=75, label=r'$\hat\mu^{MAP}|\hat\tau^{MAP},\sigma^2$')

plt.title(r"Distribution of $\mu|\tau^{MAP},\sigma^2$")

plt.xlabel(r'$\mu$')
plt.ylabel(r'$p(\mu|\tau^{MAP},\sigma^2)$')

plt.yticks([], [])

plt.legend(loc='upper left')

# %% [markdown]
# This plot is for the conditional posterior means of treatment effects, $E(\theta_j|\sigma,\tau,\mathbf{Y})$.

# %%
for j in DatGroup['Group']:
    plt.plot(TauVect, HatThetaFunc(j, TauVect), label=j)

plt.xlabel(r'$\tau$')
plt.ylabel(r'$E(\theta|\sigma^2,\tau^2,\vec{Y})$')

plt.legend()
# Out:
# /home/dmitri/.local/lib/python3.11/site-packages/numpy/lib/function_base.py:2415: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   res = asanyarray(outputs, dtype=otypes[0])

# %% [markdown]
# This plot is for the conditional posterior standard deviation of treatment effects, $\textsf{Std}(\theta_j|\sigma,\tau,\mathbf{Y})$.

# %%
for j in DatGroup['Group']:
    plt.plot(TauVect, StdThetaFunc(j, TauVect), label=j)

plt.xlabel(r'$\tau$')
plt.ylabel(r'Std$(\theta|\sigma^2,\tau^2,\vec{Y})$')

plt.legend()

# %% [markdown]
# ---

# %% [markdown]
# ## Using Pymc

# %% [markdown]
# ### Separate estimates

# %%
with pm.Model() as ModelSeparate:
    Theta = pm.Flat('Theta', shape=J)
    Obs   = pm.Normal('Obs', mu=Theta, sigma=DatGroup['SigmaJ'], observed=DatGroup['MeanGroup'])

    TraceSeparate = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Theta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:02&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 3 seconds.
# /home/dmitri/.local/lib/python3.11/site-packages/arviz/utils.py:184: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   numba_fn = numba.jit(**self.kwargs)(self.function)
# Sampling: [Obs]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>

# %%
SummarySeparate = az.summary(TraceSeparate, kind='stats', hdi_prob=1-ALPHA_LEVEL)

# %%
for j in range(J):
    plt.plot(
        [j, j],
        [SummarySeparate.iloc[j]['hdi_' + str(ALPHA_LEVEL/2*100) + '%'], SummarySeparate.iloc[j]['hdi_' + str((1-ALPHA_LEVEL/2)*100) + '%']],
        color='k')
    
plt.scatter(range(J), DatGroup['MeanGroup'], marker='D', color='k')

plt.xticks(ticks=range(J), labels=DatGroup['Group'])
plt.xlabel("School")
plt.ylabel(r"95% hightest posterior density for each $\theta$")
# Out:
# Text(0, 0.5, '95% hightest posterior density for each $\\theta$')

# %% [markdown]
# ### Complete Pooling

# %%
with pm.Model() as ModelPooling:
    Theta = pm.Flat('Theta')
    Obs   = pm.Normal('Obs', mu=Theta, sigma=DatGroup['SigmaJ'], observed=DatGroup['MeanGroup'])

    TracePooling = pm.sample()
    TracePooling.extend(pm.sample_posterior_predictive(TracePooling))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Theta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:02&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 3 seconds.
# Sampling: [Obs]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>

# %%
SummaryPooling = az.summary(TracePooling, kind='stats', group='posterior_predictive', hdi_prob=1-ALPHA_LEVEL)

# %%
plt.plot(
    [DatGroup['MeanGroup'].min(), DatGroup['MeanGroup'].max()],
    [DatGroup['MeanGroup'].min(), DatGroup['MeanGroup'].max()],
    color='r', linestyle='--'
)

plt.scatter(DatGroup['MeanGroup'], SummaryPooling['mean'], marker='D', color='k')

for j in range(J):
    plt.plot(
        [DatGroup['MeanGroup'][j], DatGroup['MeanGroup'][j]],
        [SummaryPooling.iloc[j]['hdi_' + str(ALPHA_LEVEL/2*100) + '%'], SummaryPooling.iloc[j]['hdi_' + str((1-ALPHA_LEVEL/2)*100) + '%']],
        color='k'
    )

plt.xlabel(r"$Y_j$")
plt.ylabel(r"95% prediction interval for each $Y_j$")
# Out:
# Text(0, 0.5, '95% prediction interval for each $Y_j$')

# %% [markdown]
# ### Hierarchical model

# %%
with pm.Model() as ModelHierarchical:
    Mu    = pm.Flat('Mu')
    Tau   = pm.HalfFlat('Tau')
    Theta = pm.Normal('Theta', mu=Mu, sigma=Tau, shape=J)
    Obs   = pm.Normal('Obs', mu=Theta, sigma=DatGroup['SigmaJ'], observed=DatGroup['MeanGroup'])

    TraceHierarchical = pm.sample()
    TraceHierarchical.extend(pm.sample_posterior_predictive(TraceHierarchical))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Mu, Tau, Theta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:09&lt;00:00 Sampling 4 chains, 173 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 9 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# There were 173 divergences after tuning. Increase `target_accept` or reparameterize.
# Sampling: [Obs]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>

# %%
pm.model_to_graphviz(ModelHierarchical)

# %%
SummaryHierarchical = az.summary(TraceHierarchical, group='posterior_predictive', kind='stats', hdi_prob=1-ALPHA_LEVEL)

# %%
plt.plot(
    [DatGroup['MeanGroup'].min(), DatGroup['MeanGroup'].max()],
    [DatGroup['MeanGroup'].min(), DatGroup['MeanGroup'].max()],
    color='r', linestyle='--'
)

plt.scatter(DatGroup['MeanGroup'], SummaryHierarchical['mean'], marker='D', color='k')

for j in range(J):
    plt.plot(
        [DatGroup['MeanGroup'][j], DatGroup['MeanGroup'][j]],
        [SummaryHierarchical.iloc[j]['hdi_' + str(ALPHA_LEVEL/2*100) + '%'], SummaryHierarchical.iloc[j]['hdi_' + str((1-ALPHA_LEVEL/2)*100) + '%']],
        color='k'
    )

plt.xlabel(r"$Y_j$")
plt.ylabel(r"95% prediction interval for each $Y_j$")
# Out:
# Text(0, 0.5, '95% prediction interval for each $Y_j$')

# %%
az.plot_posterior(
    TraceHierarchical
    , var_names='Theta'
    , ref_val=DatGroup['MeanGroup'].to_list()
)
# Out:
# /home/dmitri/.local/lib/python3.11/site-packages/arviz/utils.py:184: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   numba_fn = numba.jit(**self.kwargs)(self.function)
# array([[<Axes: title={'center': 'Theta\n0'}>,
#         <Axes: title={'center': 'Theta\n1'}>,
#         <Axes: title={'center': 'Theta\n2'}>,
#         <Axes: title={'center': 'Theta\n3'}>],
#        [<Axes: title={'center': 'Theta\n4'}>,
#         <Axes: title={'center': 'Theta\n5'}>,
#         <Axes: title={'center': 'Theta\n6'}>,
#         <Axes: title={'center': 'Theta\n7'}>]], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# ## Model Checking

# %% [markdown]
# Histogram of the maximum of $\theta$

# %%
_, _, _ = plt.hist(TraceHierarchical.posterior.Theta.max(axis=2).values.ravel(), bins=25, edgecolor='w')
plt.axvline(DatGroup['MeanGroup'].max(), color='r')
plt.xlabel('Largest effect')
# Out:
# Text(0.5, 0, 'Largest effect')

# %% [markdown]
# $P(\theta_1>\theta_3|\mathbf{Y})$

# %%
np.mean(TraceHierarchical.posterior.Theta[:,:,0].values.ravel() > TraceHierarchical.posterior.Theta[:,:,2].values.ravel())
# Out:
# 0.67425

# %% [markdown]
# Histograms the largest effect, $\max\{Y_j\}$.

# %%
_, _, _ = plt.hist(TraceHierarchical.posterior_predictive.Obs.max(axis=2).values.ravel(), bins=25, edgecolor='w')
plt.axvline(DatGroup['MeanGroup'].max(), color='r')
plt.xlabel('Largest effect')
# Out:
# Text(0.5, 0, 'Largest effect')

# %% [markdown]
# $P(\max\{Y_j\}\geq y_{(J)})$

# %%
np.mean(TraceHierarchical.posterior_predictive.Obs.max(axis=2).values.ravel() > DatGroup['MeanGroup'].max())
# Out:
# 0.501

# %% [markdown]
# ---

# %% [markdown]
# # Second Part

# %% [markdown]
# ## Evaluation of the models

# %% [markdown]
# ### AIC

# %% [markdown]
# AIC for separate models

# %%
lpd = sum(norm.logpdf(DatGroup['MeanGroup'], loc=DatGroup['MeanGroup'], scale=DatGroup['SigmaJ']))
k   = 8

print(round(-2*lpd, 1))
print(round(-2*(lpd - k), 1))
# Out:
# 54.6
# 70.6

# %% [markdown]
# AIC for pooled model

# %%
lpd = sum(norm.logpdf(DatGroup['MeanGroup'], loc=HatMuEmpirical, scale=DatGroup['SigmaJ']))
k   = 1

print(round(-2*lpd, 1))
print(round(-2*(lpd - k), 1))
# Out:
# 59.3
# 61.3

# %% [markdown]
# ### DIC

# %% [markdown]
# DIC for separate models

# %%
lpd = sum(norm.logpdf(DatGroup['MeanGroup'], loc=DatGroup['MeanGroup'], scale=DatGroup['SigmaJ']))

Loglike = []
pDIC = 0

for s in range(4000):
    ThetaSim = norm.rvs(size=J, loc=DatGroup['MeanGroup'], scale=DatGroup['SigmaJ'])
    Loglike.append(sum(norm.logpdf(DatGroup['MeanGroup'], loc=ThetaSim, scale=DatGroup['SigmaJ'])))

Loglike = np.array(Loglike)

pDIC = 2 * (lpd-np.mean(Loglike))
pDIC_alt = 2 * np.var(Loglike)

print(round(-2*lpd, 1))
print(round(pDIC, 1))
print(round(pDIC_alt, 1))
print(round(-2*(lpd - pDIC), 1))
print(round(-2*(lpd - pDIC_alt), 1))
# Out:
# 54.6
# 7.9
# 7.9
# 70.4
# 70.4

# %% [markdown]
# DIC for pooled model

# %%
lpd = sum(norm.logpdf(DatGroup['MeanGroup'], loc=HatMuEmpirical, scale=DatGroup['SigmaJ']))

Loglike = []
pDIC = 0

for s in range(4000):
    ThetaSim = norm.rvs(size=J, loc=HatMuEmpirical, scale=np.sqrt(VarPooledEstimate))
    Loglike.append(sum(norm.logpdf(DatGroup['MeanGroup'], loc=ThetaSim, scale=DatGroup['SigmaJ'])))

Loglike = np.array(Loglike)

pDIC = 2 * (lpd-np.mean(Loglike))
pDIC_alt = 2 * np.var(Loglike)

print(round(-2*lpd, 1))
print(round(pDIC, 1))
print(round(pDIC_alt, 1))
print(round(-2*(lpd - pDIC), 1))
print(round(-2*(lpd - pDIC_alt), 1))
# Out:
# 59.3
# 1.0
# 1.3
# 61.3
# 62.0

# %%
ThetaPosterior = TraceHierarchical.posterior.stack(sample=["chain", "draw"]).Theta.values.T

# %% [markdown]
# DIC for the hierarchical model

# %%
lpd = sum(norm.logpdf(DatGroup['MeanGroup'], loc=TraceHierarchical.posterior.Theta.mean(axis=(0,1)), scale=DatGroup['SigmaJ']))

Loglike = []

for s in range(4000):
    Loglike.append(sum(norm.logpdf(DatGroup['MeanGroup'], loc=ThetaPosterior[s], scale=DatGroup['SigmaJ'])))

Loglike = np.array(Loglike)

pDIC = 2 * (lpd-np.mean(Loglike))
pDIC_alt = 2 * np.var(Loglike)

print(round(-2*lpd, 1))
print(round(pDIC, 1))
print(round(pDIC_alt, 1))
print(round(-2*(lpd - pDIC), 1))
print(round(-2*(lpd - pDIC_alt), 1))
# Out:
# 57.2
# 3.0
# 2.7
# 63.3
# 62.7

# %% [markdown]
# ### WAIC

# %% [markdown]
# WAIC for the separate models

# %%
Lppd = 0
pWAIC1 = 0
pWAIC2 = 0

for i in range(len(DatGroup)):
    ThetaSim = norm.rvs(size=4000, loc=DatGroup['MeanGroup'][i], scale=DatGroup['SigmaJ'][i])
    Loglike = norm.logpdf(DatGroup['MeanGroup'][i], loc=ThetaSim, scale=DatGroup['SigmaJ'][i])
    Lppd += logsumexp(Loglike) - np.log(4000)
    pWAIC1 += Loglike.mean()
    pWAIC2 += np.var(Loglike)

pWAIC1 = 2 * (Lppd - pWAIC1)

print(round(-2*Lppd, 1))
print(round(pWAIC1, 1))
print(round(pWAIC2, 1))
print(round(-2*(Lppd - pWAIC1), 1))
print(round(-2*(Lppd - pWAIC2), 1))
# Out:
# 60.2
# 2.4
# 3.9
# 65.0
# 68.1

# %% [markdown]
# WAIC for the pooled model

# %%
Lppd = 0
pWAIC1 = 0
pWAIC2 = 0

for i in range(len(DatGroup)):
    ThetaSim = norm.rvs(size=4000, loc=HatMuEmpirical, scale=np.sqrt(VarPooledEstimate))
    Loglike = norm.logpdf(DatGroup['MeanGroup'][i], loc=ThetaSim, scale=DatGroup['SigmaJ'][i])
    Lppd += logsumexp(Loglike) - np.log(4000)
    pWAIC1 += Loglike.mean()
    pWAIC2 += np.var(Loglike)

pWAIC1 = 2 * (Lppd - pWAIC1)

print(round(-2*Lppd, 1))
print(round(pWAIC1, 1))
print(round(pWAIC2, 1))
print(round(-2*(Lppd-pWAIC1), 1))
print(round(-2*(Lppd-pWAIC2), 1))
# Out:
# 59.8
# 0.6
# 0.7
# 61.0
# 61.2

# %% [markdown]
# WAIC for the hierarchical model

# %%
TraceThetaAux = ThetaPosterior.T

Lppd = 0
pWAIC1 = 0
pWAIC2 = 0

for i in range(len(DatGroup)):
    Loglike = norm.logpdf(DatGroup['MeanGroup'][i], loc=TraceThetaAux[i], scale=DatGroup['SigmaJ'][i])
    Lppd += logsumexp(Loglike) - np.log(4000)
    pWAIC1 += Loglike.mean()
    pWAIC2 += np.var(Loglike)

pWAIC1 = 2 * (Lppd - pWAIC1)

print(round(-2*Lppd, 1))
print(round(pWAIC1, 1))
print(round(pWAIC2, 1))
print(round(-2*(Lppd - pWAIC1), 1))
print(round(-2*(Lppd - pWAIC2), 1))
# Out:
# 59.2
# 1.1
# 1.4
# 61.3
# 62.0

# %% [markdown]
# ---

# %% [markdown]
# ## Using PyMC

# %%
_ = pm.compute_log_likelihood(TraceSeparate, model = ModelSeparate)
_ = pm.compute_log_likelihood(TracePooling, model = ModelPooling)
_ = pm.compute_log_likelihood(TraceHierarchical, model = ModelHierarchical)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data

# %%
CompareTable= az.compare(
    {
        "No Pooling": TraceSeparate
        , "Complete Pooling": TracePooling
        , "Hierarchical": TraceHierarchical
    }
    , ic = 'waic' #'waic' or 'loo'
    , scale = 'deviance'
)
# Out:
# /home/dmitri/.local/lib/python3.11/site-packages/arviz/stats/stats.py:1645: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(

# %%
CompareTable.round(2)
# Out:
#                   rank  elpd_waic  p_waic  elpd_diff  weight    se   dse  \
# Complete Pooling     0      61.09    0.66       0.00     1.0  2.19  0.00
# Hierarchical         1      61.99    1.41       0.89     0.0  1.74  0.62
# No Pooling           2      68.10    3.98       7.01     0.0  1.35  1.82
#
#                   warning     scale
# Complete Pooling    False  deviance
# Hierarchical        False  deviance
# No Pooling           True  deviance

# %%
_, axes = plt.subplots(1,1)

az.plot_compare(
    CompareTable
    , textsize = 11
    , figsize = (10,5)
    , ax = axes
    , title =  False
    )

axes.set_xlabel('WAIC')
axes.legend(["WAIC best model", "WAIC",  "WAIC difference"])
